# %%
import sqlite3
import pandas as pd
import datetime

# %%
conn = sqlite3.connect('chat.db')
c = conn.cursor()

# %%
cmd1 = 'SELECT ROWID, text, handle_id, \
            datetime(date + strftime(\'%s\',\'2001-01-01\'), \'unixepoch\') as date_utc \
            FROM message T1 \
            INNER JOIN chat_message_join T2 \
                ON T2.chat_id=10 \
                AND T1.ROWID=T2.message_id \
            ORDER BY T1.date'
c.execute(cmd1)
df_msg = pd.DataFrame(c.fetchall(), columns=['id', 'text', 'sender', 'time'])

# %%
cmd2 = 'SELECT ROWID, text, handle_id, \
            datetime(date + strftime(\'%s\',\'2001-01-01\'), \'unixepoch\') as date_utc \
            FROM message T1 \
            INNER JOIN chat_message_join T2 \
                ON T1.ROWID=T2.message_id \
            ORDER BY T2.chat_ID, T1.date'
c.execute(cmd2)
all_msg = pd.DataFrame(c.fetchall(), columns=['id','text','sender','time'])

# %%
all_msg
# Out:
#           id                                               text  sender  \
# 0          1                  My phone charger is at your home!       1
# 1          2  okay so I didn't eat anything for dinner last ...       1
# 2          3                     You are the opposite of sick.        1
# 3          4               But you should still eat something.        1
# 4          5            I will go to speilmoons and get a bagel       1
# 5          6  I've been taking a lot more lactaid pills that...       1
# 6          7           !!!!!!! THERE IS A NEW WHOSE LINE COMING       1
# 7          8                                               WHAT       1
# 8          9                                          Omg Colin       1
# 9         10                                          You tease       1
# 10        11                     Also GoT comes back THIS MONTH       1
# 11        12  Oh man, Aisha Tyler is going to host it. She v...       1
# 12        13  http://s3-ec.buzzfed.com/static/enhanced/webdr...       1
# 13        14                                            weeeird       1
# 14        15                      polish restaurant for dinner?       1
# 15        16  Google Offers has a coupon for 20% off online ...       1
# 16        17                                  If you're hungry!       1
# 17        18               It has really good reviews on Yelp.        1
# 18        19                            I am getting hungry now       1
# 19        20                         getting caffeine euphoria        1
# 20        21                  listening to some hip social talk       1
# 21        22                                      at speilman's       1
# 22        23                               I love distributions       1
# 23        25                               I am such a Bayesian       1
# 24        26                       ugh I fucking want pie again       1
# 25        27                     like a blueberry peach cobbler       1
# 26        24                                      Alden Bayes.        1
# 27        28  Let's check out that pie place on Division tha...       1
# 28        29                                what was it called?       1
# 29        30                                    Lauretta Jean's       1
# ...      ...                                                ...     ...
# 81709  82259                       https://tinyurl.com/y9mbjop9       0
# 81710  82260  on mobile it only shows the "it's a pleasure" ...     164
# 81711  82262                                          lol noooo       0
# 81712  82263                           yeah it's not for phones       0
# 81713  82264  yeah i didn’t even know it asked for your emai...     164
# 81714  82265                    i’m scared to enter my email in     164
# 81715  82266                                                why       0
# 81716  82268                  why are you collecting our emails     164
# 81717  82269                                       to email you       0
# 81718  82270                             Oh wow I fucked up lol       6
# 81719  82271                               I failed to promise        6
# 81720  82272              wow yeah now you look like an asshole       0
# 81721  82273                 I got 2 of my friends to do it lol     164
# 81722  82274                                          lol I saw       0
