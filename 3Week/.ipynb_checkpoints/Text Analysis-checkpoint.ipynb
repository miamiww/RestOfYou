# %%
import sqlite3
import pandas as pd
import datetime

# %%
conn = sqlite3.connect('chat.db')
c = conn.cursor()

# %%
cmd1 = 'SELECT ROWID, text, handle_id, \
            datetime(date + strftime(\'%s\',\'2001-01-01\'), \'unixepoch\') as date_utc \
            FROM message T1 \
            INNER JOIN chat_message_join T2 \
                ON T2.chat_id=10 \
                AND T1.ROWID=T2.message_id \
            ORDER BY T1.date'
c.execute(cmd1)
df_msg = pd.DataFrame(c.fetchall(), columns=['id', 'text', 'sender', 'time'])

# %%
df_msg
# Out:
#         id                                               text  sender  \
# 0      985         what if we went to the ski cabin tomorrow        0
# 1      986                                                  🙊       6
# 2      987                                      I would do it       6
# 3      988                     I've been thinking about that!       7
# 4      989     I'll do it if I'm less sick than I am today...       7
# 5      990                       I think we should just do it       0
# 6      991         Yeah Ari I think it will heal you actually       6
# 7      992                         yeah it'll be restorative        0
# 8      993                        I think you might be right        7
# 9      994                                      Yeah let's do       7
# 10     995                               Ur a bloody ledge m8       6
# 11    1055                                      it's full 😭😭😭       0
# 12    1056                              Noooooooooooooooooooo       6
# 13    1057                                  How can be???????       6
# 14    1058                          I was getting so excited!       7
# 15    1059         Alden I told you I was cursed!!!!!!!!!!!!!       6
# 16    1060  I know I just tried to make a reservation and ...       0
# 17    1061                                                 ☹️       7
# 18    1062                    Do you see a time when it's not       6
# 19    1063           next Saturday but we can't book that yet       0
# 20    1064                              When does it open up?       6
# 21    1065                                          tomorrow        0
# 22    1066                   I'd be down next weekend I think       0
# 23    1067                                      Me2 obviously       6
# 24    1069  It's a talking heads at spielman type of morni...       6
# 25    1070                                                  😶       7
# 26    1071                                                  😔       0
# 27    1086          Alden can you go reserve the ski cabin rn       6
# 28    1087                                                yes       0
# 29    1088              you and Ari have to do it separately        0
# ..     ...                                                ...     ...
# 665  62733                          some district of tokyo???       0
# 666  62734                                               Lmao       6
# 667  62735                       like it comes out of nowhere       0
# 668  62736  Did a spit take when I read what ailes's wife ...       6
# 669  62737                      truly, he died as he lived...       0
# 670  62738                                                  ￼       0
# 671  62871             just looked up the lyrics to catallena       0
# 672  62872  Oh my, she’s so great, I’ve fallen for her\nEv...       0
# 673  62873                                                  😍       0
# 674  62874                                                Omg       7
# 675  62875                                                Yes       7
# 676  62876      when they are crying I think it is this part:       0
# 677  62877  Softly, softly,\nMelting,\nMelting\nShivering,...       0
# 678  62878                                                Omg       6
# 679  62880                                          iknoright       0
# 680  62883  Guess who's got two thumbs and somehow lost he...       6
# 681  62884                                    👉🏼 this girl 👈🏼       6
# 682  62885                                           oh noooo       0
